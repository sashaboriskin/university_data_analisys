# %% [markdown]
# В этом примере мы покажем, как с помощью API Яндекс.Геокодера можно преобразовать адреса в геокоординаты, с которым можно работать в [Datalens](https://datalens.yandex.ru)

# %% [markdown]
# ## Установка библиотек
#
#  * requests для API Геокодера
#  * clickhouse-driver для Clickhouse

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /Users/mgordenko/opt/anaconda3/lib/python3.9/site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mgordenko/opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/mgordenko/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mgordenko/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mgordenko/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install clickhouse-driver
# Out:
# Collecting clickhouse-driver
#   Downloading clickhouse_driver-0.2.6-cp39-cp39-macosx_10_9_x86_64.whl (185 kB)
#      |████████████████████████████████| 185 kB 1.6 MB/s eta 0:00:01
# Collecting tzlocal
#   Downloading tzlocal-5.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: pytz in /Users/mgordenko/opt/anaconda3/lib/python3.9/site-packages (from clickhouse-driver) (2021.3)
# Installing collected packages: tzlocal, clickhouse-driver
# Successfully installed clickhouse-driver-0.2.6 tzlocal-5.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Получение ключа для API Геокодера
#
# В переменную API_KEY нужно записать свой ключ для API Геокодера.
# Получить ключ можно по [ссылке](https://yandex.ru/dev/maps/geocoder/)

# %%
API_KEY = ''

# %% [markdown]
# ## Работа с API Геокодера
#
# Напишем небольшой класс для работы с Геокодером

# %%
import requests
from dataclasses import dataclass

@dataclass
class YandexGeocoder:
    api_key: str
    geocoder_url: str = 'https://geocode-maps.yandex.ru/1.x'

    def adress_to_geopoint(self, address: str) -> str:
        """
        Преобразование адреса в геокоординаты в формате Datalens
        """
        response = requests.get(self.geocoder_url, params={
            'apikey': self.api_key,
            'geocode': address,
            'format': 'json',
        })
        response.raise_for_status()

        result = response.json()['response']['GeoObjectCollection']['featureMember']
        if not result:
            return None

        lat, lon = result[0]['GeoObject']['Point']['pos'].split(' ')
        return self._to_datalens_format(lon, lat)
    
    def _to_datalens_format(self, lon, lat):
        return f'[{lon},{lat}]'

# %% [markdown]
# ## Получение данных
#
# Будем работать с данными из демонстрационного Clickhouse [Datalens](https://datalens.yandex.ru).
#
# На первом шаге подготовим клиент Clickhouse

# %%
from clickhouse_driver import Client as CHClient

ch_client = CHClient(
    'rc1a-ckg8nrosr2lim5iz.mdb.yandexcloud.net',
    user='samples_ro',
    password='MsgfcjEhJk',
    database='samples',
    port=9440,
    secure=True,
)

# %% [markdown]
# Затем выгрузим данные из таблицы в переменную ch_data

# %%
import pandas as pd
all_files = ["rus_cityes.csv"]
df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
df
# Out:
#    Russia          moscow
# 0  Russia   rostov-on-don

# %%
ch_data2 = ch_data[0:1000]

# %%
 
for i in range(len(ch_data)):
    ch_data[i] = "Russia, " + ch_data[i]
ch_data
# Out:
# ['Russia, Kulunda',
#  'Russia, Spitsevka',
#  'Russia, Pokanaevka',
#  'Russia, Belorus',
#  'Russia, Pudost',
#  'Russia, Nema',
#  'Russia, Voronezhskoe Malanino',
#  'Russia, Rzhevskoe',
#  'Russia, Nekrasovskoe',
#  'Russia, Vakhrushi (pgt)',
#  'Russia, Slyudyanka',
#  'Russia, Duminichi',
#  'Russia, Sződ',
#  'Russia, Omutinskoe',
#  'Russia, Berezovo',
#  'Russia, Blagoveschensk',
#  'Russia, Zhilgorodok',
#  'Russia, Obvinsk',
#  'Russia, Sosnovy',
#  'Russia, Fedorovka (olkhovskoe S/p)',
#  'Russia, Terengul (selo)',
#  'Russia, Vorkuta',
#  'Russia, Nizhnyaya Ternovka',
#  'Russia, Cherdyn',
#  'Russia, Zakharov',
#  'Russia, Yutaza',
#  'Russia, Nizhneangarsk',
#  'Russia, Goryachy Klyuch',
#  'Russia, Lepley',
#  'Russia, Romodanovo',
#  'Russia, Lyskovo',
#  'Russia, Moshenskoe',
#  'Russia, Shinsha',
#  'Russia, Bolshoy',
#  'Russia, Galenki',
#  'Russia, Grunin Vorgol (selo)',
#  'Russia, Ostrovskoe (poselok)',
#  'Russia, Brusentsevo',
#  'Russia, Valday',
#  'Russia, Makushino',
#  'Russia, Slavyansk-Na-Kubani',
#  'Russia, Sandovo',
#  'Russia, Chernorechenskaya',
#  'Russia, Petropavlovsk',
#  'Russia, Yalanskoe',
#  'Russia, Iltyakovo',
#  'Russia, Zeleny',
#  'Russia, Golovchino',
#  'Russia, Lazarevo',
#  'Russia, Norma',
#  'Russia, Sudak',
#  'Russia, Panovy Kusty',
#  'Russia, Leningradskaya',
#  'Russia, Tigan-Bulyak',
#  'Russia, Zamzor',
#  'Russia, Lenki',
#  'Russia, Rasskazovo',
#  'Russia, Dneprovskoe',
#  'Russia, Kurovskoe',
#  'Russia, Kokorevka',
#  'Russia, Severo-Eniseysky',
#  'Russia, Vanino Pole',
#  'Russia, Tyubuk',
#  'Russia, Medet',
#  'Russia, Snytkino',
#  'Russia, Vtorovo',
#  'Russia, Molodogvardeysky',
#  'Russia, Kraskino',
#  'Russia, Kamenolomnya',
#  'Russia, Malaya Kamenka',
#  'Russia, Verkhnie Yuri',
#  'Russia, Usta',
#  'Russia, Elovo',
#  'Russia, Kantyshevo',
#  'Russia, Krasnaya Sloboda',
#  'Russia, Shali',
#  'Russia, Orlik',
#  'Russia, Kremyanoe',
#  'Russia, Dorgeli',
#  'Russia, Kurakino',
#  'Russia, Karinovka',
#  'Russia, Voyvozh',
#  'Russia, Pokachi',
#  'Russia, Bereznik (selo)',
#  'Russia, Stary Kryazhim',
#  'Russia, Iki-Burul',
#  'Russia, Rybachye',
#  'Russia, Ryatamak',
#  'Russia, Novaya Bryan',
#  'Russia, Tokyo',
#  'Russia, Novaya Chara',
#  'Russia, Khorinsk',
#  'Russia, Chulym',
#  'Russia, Ramon',
#  'Russia, Butrakhty',
#  'Russia, Toropets',
#  'Russia, Zaglyadino',
#  'Russia, Kazan (selo)',
#  'Russia, Ilka',
#  'Russia, Kuznets',
#  'Russia, Khonkholoy',
#  'Russia, Borovlyanka',
#  'Russia, Prichulymsky',
#  'Russia, Dzhaga',
#  'Russia, Azovsky',
#  'Russia, Antsiferovsky Bor',
#  'Russia, Verkhnyaya Zima',
#  'Russia, Tad-Magitl',
#  'Russia, Bolshekrepinskaya',
#  'Russia, Labytnangi',
#  'Russia, Konstantinovsky',
#  'Russia, Tsentralnaya Usadba Sovkhoza «serp I Molot»',
#  'Russia, Novichikha',
#  'Russia, Yurty',
#  'Russia, Shatki',
#  'Russia, Meshkovskaya',
#  'Russia, Zdvinsk',
#  'Russia, Karagush',
#  'Russia, Turgenevo (turgenevskoe S/p)',
#  'Russia, Sterlibashevo',
#  'Russia, Svatovo',
#  'Russia, Nikolskoe 1-E',
#  'Russia, Korolevo (krasavino G/p)',
#  'Russia, Orichi',
#  'Russia, Respublika',
#  'Russia, Khrustalny',
#  'Russia, Kalinka',
#  'Russia, Kesova Gora',
#  'Russia, Sevastopol (selo)',
#  'Russia, Armyansk',
#  'Russia, Tenki',
#  'Russia, Novye Gorki',
#  'Russia, Stupino',
#  'Russia, Lomonosov',
#  'Russia, Afanasyevka',
#  'Russia, Verbovsky',
#  'Russia, Zhizdra',
#  'Russia, Biryulinskogo Zverosovkhoza',
#  'Russia, Alexandrovskoe',
#  'Russia, Emeshevo',
#  'Russia, Krasnoe-Na-Volge',
#  'Russia, Ust-Koxa',
#  'Russia, Lyubim',
#  'Russia, Tugulym',
#  'Russia, Tavrichanka',
#  'Russia, Raychikhinsk',
#  'Russia, 44 Razezd',
#  'Russia, Vilyuysk',
#  'Russia, Sytomino',
#  'Russia, Emva',
#  'Russia, Kitovo',
#  'Russia, Izmalkovo',
#  'Russia, Luna',
#  'Russia, Prokoshevo',
#  'Russia, Gus-Zhelezny',
#  'Russia, Bobrov',
#  'Russia, Karievo',
#  'Russia, Tyulgan (stantsia)',
#  'Russia, Sovetskoe',
#  'Russia, Gorodskoy Okrug Gorod Yakutsk',
#  'Russia, Krasnoznamenka',
#  'Russia, Chuguny',
#  'Russia, Cherlak',
#  'Russia, Rovenki',
#  'Russia, Zheshart',
#  'Russia, Lebedevka',
#  'Russia, Babynino',
#  'Russia, Novopetrovskoe',
#  'Russia, Dzerzhinsky',
#  'Russia, Arabkaevo',
#  'Russia, Pyskor',
#  'Russia, Shabelskoe',
#  'Russia, Krush',
#  'Russia, Zheleznogorsk-Ilimsky',
#  'Russia, Donskoe',
#  'Russia, Konchinka',
#  'Russia, Alexandrov',
#  'Russia, Dolgovitsa',
#  'Russia, Zavety Ilicha',
#  'Russia, Bogoslovka',
#  'Russia, Novoorsk',
#  'Russia, Fershampenuaz',
#  'Russia, Pogadaevo',
#  'Russia, Molokovo',
#  'Russia, Zhigulevsky',
#  'Russia, Kurga',
#  'Russia, Gorodets',
#  'Russia, Volodarsk',
#  'Russia, Myski',
#  'Russia, Pizhanka',
#  'Russia, Mesker-Yurt',
#  'Russia, Krasnaya Gora',
#  'Russia, Matyushino',
#  'Russia, Alekhnovo',
#  'Russia, Yazhelbitsy',
#  'Russia, Vyazma-Bryanskaya',
#  'Russia, Sukhobezvodnoe (derevnya)',
#  'Russia, Sokol',
#  'Russia, Tatarsky Maloyaz',
#  'Russia, Asekeevo (selo)',
#  'Russia, Pchevzha',
#  'Russia, Ismaylovo',
#  'Russia, Novodzherelievskaya',
#  'Russia, Aserkhovo',
#  'Russia, Nizhnesortymsky',
#  'Russia, Perevalnoe',
#  'Russia, Gorki',
#  'Russia, Karpogory',
#  'Russia, Kulikovka',
#  'Russia, Teguldet',
#  'Russia, Glubokoe (kamennogorskoe G/p)',
#  'Russia, Lisya Gora',
#  'Russia, Padovka',
#  'Russia, Svetlogorsk',
#  'Russia, Chunsky',
#  'Russia, Snezhnogorsk',
#  'Russia, Natukhaevskaya',
#  'Russia, Duldug',
#  'Russia, Girvas',
#  'Russia, Kiev (derevnya)',
#  'Russia, Krasnoslobodsk',
#  'Russia, Tsarev',
#  'Russia, Novy Buyan',
#  'Russia, Knevitsy (poselok)',
#  'Russia, Novopanskoe',
#  'Russia, Razvilnoe',
#  'Russia, Pobeda',
#  'Russia, Pochtovoe',
#  'Russia, Snezhinsk',
#  'Russia, Urengoy',
#  'Russia, Sadovoe',
#  'Russia, Agidel',
#  'Russia, Moskovsky',
#  'Russia, Vokhtoga (pgt)',
#  'Russia, Selty',
#  'Russia, Kolpna',
#  'Russia, Yakshur-Bodya',
#  'Russia, Cherbi',
#  'Russia, Dolgoderevenskoe',
#  'Russia, Voznesenovka',
#  'Russia, Rovdino',
#  'Russia, Yaroslavl (derevnya)',
#  'Russia, Mindyak',
#  'Russia, Ladushkin',
#  'Russia, Krasnogorsky',
#  'Russia, Alexeevskoe',
#  'Russia, Starokucherbaevo',
#  'Russia, Sovkhoza «voronezhskiy»',
#  'Russia, Mudyuga ',
#  'Russia, Primorsk',
#  'Russia, Temyasovo',
#  'Russia, Karvudzhem',
#  'Russia, Sibir (poselok)',
#  'Russia, Linevo',
#  'Russia, Mogilev',
#  'Russia, Rukhtino',
#  'Russia, Pochekuevo',
#  'Russia, Sumkino',
#  'Russia, Klushino',
#  'Russia, Kurkino',
#  'Russia, Belyanka',
#  'Russia, Vostochny',
#  'Russia, Naryan-Mar',
#  'Russia, Adygeysk',
#  'Russia, Cheburenki',
#  'Russia, Mezhgorye',
#  'Russia, Fateevy',
#  'Russia, Shpalozavod',
#  'Russia, Amderma',
#  'Russia, Isetskoe',
#  'Russia, Chernoistochinsk',
#  'Russia, Ignatovka',
#  'Russia, Bobrujsk',
#  'Russia, Staroe Shaygovo',
#  'Russia, Gubkino',
#  'Russia, Nurma',
#  'Russia, Kyzyl-Tash',
#  'Russia, Shatunovo',
#  'Russia, Tenyaevo',
#  'Russia, Vedlozero',
#  'Russia, Filimonovo',
#  'Russia, Makaryev',
#  'Russia, Kishinevka',
#  'Russia, Solnechnogorsk-7',
#  'Russia, Kulaevo',
#  'Russia, Rīga',
#  'Russia, Zelenodolsk',
#  'Russia, Grodno',
#  'Russia, Dubinino',
#  'Russia, Boloto',
#  'Russia, Druzhinino',
#  'Russia, Khumalag',
#  'Russia, Bardovo',
#  'Russia, Troitsa',
#  'Russia, Mamoshino',
#  'Russia, Vozrozhdenie (poselok)',
#  'Russia, Sorum',
#  'Russia, Malyachkino',
#  'Russia, Birsk',
#  'Russia, Velikie Suki',
#  'Russia, Dzhida',
#  'Russia, Vargashi (rp)',
#  'Russia, Chernyakhovsk',
#  'Russia, Poedugi',
#  'Russia, Khatanga',
#  'Russia, Ledmozero',
#  'Russia, Tereben (derevnya)',
#  'Russia, Shovkra',
#  'Russia, Asino',
#  'Russia, Kamyshinsky',
#  'Russia, Kurlovo',
#  'Russia, Dedinovo',
#  'Russia, Tatischevo',
#  'Russia, Shingak-Kul',
#  'Russia, Putilkovo',
#  'Russia, Shaygino',
#  'Russia, Chuvashskoe Drozhzhanoe',
#  'Russia, Ytyk-Kyuel',
#  'Russia, Tubinsky',
#  'Russia, Gurulevo',
#  'Russia, Novye Shimkusy',
#  'Russia, Gryazovets',
#  'Russia, Novorossiysky',
#  'Russia, Zudilovo',
#  'Russia, Tyret 1-Ya',
#  'Russia, Novoyangelka',
#  'Russia, Krasnaya Gorka (selo)',
#  'Russia, Emetsk',
#  'Russia, Kamensk-Uralsky Gorodskoy Okrug',
#  'Russia, Nikolo-Pavlovskoe',
#  'Russia, Tatarstan',
#  'Russia, Kamyshenka',
#  'Russia, Shebalov',
#  'Russia, Kingisepp',
#  'Russia, Letnyaya Stavka',
#  'Russia, Sumy',
#  'Russia, Andreevo',
#  'Russia, Palekh',
#  'Russia, Bolokhovo',
#  'Russia, Vizhay',
#  'Russia, Navoloki',
#  'Russia, Divnogorsk',
#  'Russia, Kharkovskoe',
#  'Russia, Gorodki',
#  'Russia, Russky Kameshkir',
#  'Russia, Tolstoy-Yurt',
#  'Russia, Bystry Istok',
#  'Russia, Rzhaxa',
#  'Russia, Novolisino (fornosovskoe G/p)',
#  'Russia, Kireevsk',
#  'Russia, Kola',
#  'Russia, Molodi',
#  'Russia, Volot (derevnya)',
#  'Russia, Fokino',
#  'Russia, Topsa',
#  'Russia, Murzitsy',
#  'Russia, Charomskoe',
#  'Russia, Barvikha (poselok)',
#  'Russia, Sirius',
#  'Russia, Beloyarka',
#  'Russia, Kandry',
#  'Russia, Tungor',
#  'Russia, Kchun-Kazmalyar',
#  'Russia, Malaya Glushitsa',
#  'Russia, Tunoshna',
#  'Russia, Kamyshi',
#  'Russia, Verkh-Chita',
#  'Russia, Podberezye',
#  'Russia, Kursk (derevnya)',
#  'Russia, Novopokrovskaya',
#  'Russia, Kuznechnoe',
#  'Russia, Botulu',
#  'Russia, Krasnoe Seltso',
#  'Russia, Sukhoroslovo',
#  'Russia, Polovinnoe',
#  'Russia, Nartan',
#  'Russia, Bym',
#  'Russia, Kuznetsovka',
#  'Russia, Sokolskoe',
#  'Russia, Mistsevo (poselok)',
#  'Russia, Limbyayakha',
#  'Russia, Bobrovsky',
#  'Russia, Kaluga (selo)',
#  'Russia, Shexna (pgt)',
#  'Russia, Severomorsk-3',
#  'Russia, Petergof',
#  'Russia, Ukhovsky',
#  'Russia, Malye Derbety',
#  'Russia, Rogovsky',
#  'Russia, Mordovskaya Polyana',
#  'Russia, Izberbash',
#  'Russia, Sura',
#  'Russia, Mokushino',
#  'Russia, Dedenevo',
#  'Russia, Zaigraevo',
#  'Russia, Meteor',
#  'Russia, Korenovsk',
#  'Russia, Maly Ray',
#  'Russia, Mikun (derevnya)',
#  'Russia, Mirgorodsky',
#  'Russia, Meschegarovo',
#  'Russia, Gelendzhik',
#  'Russia, Ladva-Vetka',
#  'Russia, Verkhovye',
#  'Russia, Primorsky',
#  'Russia, Dyektiek',
#  'Russia, Medyana',
#  'Russia, Kichmenga',
#  'Russia, Galashki',
#  'Russia, Kamyshlov',
#  'Russia, Tixi',
#  'Russia, Stepankovo',
#  'Russia, Liman',
#  'Russia, Grayvoron',
#  'Russia, Romny',
#  'Russia, Yamanchurino',
#  'Russia, Platonovka',
#  'Russia, Kachelay',
#  'Russia, Alexeevsky',
#  'Russia, Novokhopersk',
#  'Russia, Aznakaevo',
#  'Russia, Pervomayskoe',
#  'Russia, Starye Aybesi',
#  'Russia, Novocheboxarsk',
#  'Russia, Kimovsk',
#  'Russia, Lazo',
#  'Russia, Novy Byt',
#  'Russia, Uvelsky',
#  'Russia, Proletarsky',
#  'Russia, Biryusinsk',
#  'Russia, Krutikha',
#  'Russia, Lek (poselok)',
#  'Russia, Kramatorsk',
#  'Russia, Ozernoe',
#  'Russia, Sever',
#  'Russia, Otradovka',
#  'Russia, Zaozersk',
#  'Russia, Kyylud',
#  'Russia, Ulu-Yul',
#  'Russia, Ungun Teryachi',
#  'Russia, Sadovy',
#  'Russia, Alexandrovsky Zavod',
#  'Russia, Lavrovskaya',
#  'Russia, Oykha',
#  'Russia, Kalnibolotskaya',
#  'Russia, Keres',
#  'Russia, Chicha',
#  'Russia, Lyuban',
#  'Russia, Slavgorodskoe',
#  'Russia, Chontaul',
#  'Russia, Alexandrovka',
#  'Russia, Novy Vasyugan',
#  'Russia, Mechetlino',
#  'Russia, Chelkasy',
#  'Russia, Narovchatka',
#  'Russia, Sibirskie Ogni',
#  'Russia, Bavleny (selo)',
#  'Russia, Chernyshevsky',
#  'Russia, Meneuztamak',
#  'Russia, Koslan',
#  'Russia, Novorossiyskoe',
#  'Russia, Kiritsy',
#  'Russia, Gladyshevo',
#  'Russia, Chazhemto',
#  'Russia, Goritsy',
#  'Russia, Revda 3-Ya',
#  'Russia, Kuluevo',
#  'Russia, Ikovka',
#  'Russia, Tsipya',
#  'Russia, Chernyakino',
#  'Russia, Nes',
#  'Russia, Likino-Dulevo',
#  'Russia, Velikaya Niva',
#  'Russia, Argayash',
#  'Russia, Chulman',
#  'Russia, Shokhovo (derevnya)',
#  'Russia, Khrenovoe',
#  'Russia, Kuchkovo',
#  'Russia, Koygorodok',
#  'Russia, Sverdlovskaya',
#  'Russia, Shagaevo',
#  'Russia, Shorchekasy',
#  'Russia, Kyzyl-Ozek',
#  'Russia, Cheremukhovo',
#  'Russia, Souzga',
#  'Russia, Ozerki (stantsia)',
#  'Russia, Shagonar',
#  'Russia, Kamensk-Shakhtinsky',
#  'Russia, Sherbakul',
#  'Russia, Lodeyka',
#  'Russia, Bolshaya Glushitsa',
#  'Russia, Samut Sakhon',
#  'Russia, Solikamsk',
#  'Russia, Velikooktyabrsky',
#  'Russia, 1 Km Avtodorogi Irkutsk-Markova Territoria',
#  'Russia, Grabovo',
#  'Russia, Khromtsovo',
#  'Russia, Nezlobnaya',
#  'Russia, Dzerzhinskoe',
#  'Russia, Zilgi',
#  'Russia, Leontyevo',
#  'Russia, Stary Oskol',
#  'Russia, Bakhtigildino',
#  'Russia, Korolyov',
#  'Russia, Timiryazevsky',
#  'Russia, Simferopol',
#  'Russia, Siva',
#  'Russia, Aramil 2',
#  'Russia, Luchshevo',
#  'Russia, Barun',
#  'Russia, Vyshkovo',
#  'Russia, Severomuysk',
#  'Russia, Dobryanka',
#  'Russia, Tabory',
#  'Russia, Artyshta',
#  'Russia, Elegest',
#  'Russia, Fominki',
#  'Russia, Ilino',
#  'Russia, Santa Marta',
#  'Russia, Dzhabyk',
#  'Russia, Kitay Gora',
#  'Russia, Italmas',
#  'Russia, Farn',
#  'Russia, Novy Miass',
#  'Russia, Batagay',
#  'Russia, Tolyen',
#  'Russia, Borisoglebskoe',
#  'Russia, Imeni Sverdlova',
#  'Russia, Cherkessky',
#  'Russia, Manushkino',
#  'Russia, Gagarino',
#  'Russia, Khakurinokhabl',
#  'Russia, Sababash',
#  'Russia, Baley',
#  'Russia, Arya',
#  'Russia, Srednesibirsky',
#  'Russia, Vozhega',
#  'Russia, Konevo',
#  'Russia, Kiknur',
#  'Russia, Domna',
#  'Russia, Zueva',
#  'Russia, Pleshanovo',
#  'Russia, Khonuu',
#  'Russia, Vostok',
#  'Russia, Teykovo',
#  'Russia, Dergachi',
#  'Russia, Krapivensky-1',
#  'Russia, Sannikovo',
#  'Russia, Narmonka',
#  'Russia, Urgala',
#  'Russia, Novaya Maka',
#  'Russia, Ulanovka',
#  'Russia, Mshinskaya',
#  'Russia, Kyzylbay',
#  'Russia, Karsun',
#  'Russia, Novoagansk',
#  'Russia, Letnik',
#  'Russia, Stary Nadym',
#  'Russia, Novy Ray',
#  'Russia, Tatil',
#  'Russia, Narimanov',
#  'Russia, Shatura',
#  'Russia, Kadryakovo',
#  'Russia, Iogach',
#  'Russia, Mayak',
#  'Russia, Chernokozovo',
#  'Russia, Oryol (derevnya)',
#  'Russia, Ardatov',
#  'Russia, Grachev',
#  'Russia, Masalovka',
#  'Russia, Lukyanovka',
#  'Russia, Povarkasy',
#  'Russia, Protichka',
#  'Russia, Chechen-Aul',
#  'Russia, Pushka',
#  'Russia, Raduzhny',
#  'Russia, Chutay',
#  'Russia, Konstantinovo',
#  'Russia, Vyatskie Polyany',
#  'Russia, Aminevo',
#  'Russia, Semenov',
#  'Russia, Starobelsk',
#  'Russia, Vedenyapino',
#  'Russia, Kamenetsky',
#  'Russia, Kashary',
#  'Russia, Taman',
#  'Russia, Vladivostoxkoe Shosse 40 Km',
#  'Russia, Kistendey',
#  'Russia, Mazurka',
#  'Russia, Vasilyevo',
#  'Russia, Yarensk',
#  'Russia, Kalashnikovo',
#  'Russia, Staroyuryevo',
#  'Russia, Shadchi',
#  'Russia, Kodinsk',
#  'Russia, Karpinsk',
#  'Russia, Chudinovo',
#  'Russia, Stary Kurdym',
#  'Russia, Sretensk',
#  'Russia, Usmanovo',
#  'Russia, Teploozersk',
#  'Russia, Skopin',
#  'Russia, Mamakan',
#  'Russia, Olkhovka',
#  'Russia, Erzin',
#  'Russia, Rudovka',
#  'Russia, Dinskaya',
#  'Russia, Kamennomostsky',
#  'Russia, Priobye',
#  'Russia, Krasnogoryevka',
#  'Russia, Buinsk',
#  'Russia, Elektrougli',
#  'Russia, Kushva',
#  'Russia, Yartsevo-Surmenevo',
#  'Russia, Suzun',
#  'Russia, Urukh',
#  'Russia, Tyaterbash',
#  'Russia, Goryachinsk',
#  'Russia, Biserovo',
#  'Russia, Gorokhovets',
#  'Russia, Bodaybo',
#  'Russia, Dnipro (Dnipropetrovsk)',
#  'Russia, Kucherbaevo',
#  'Russia, Kotelnich',
#  'Russia, Novokizhinginsk',
#  'Russia, Bokhan',
#  'Russia, Sukaevka',
#  'Russia, Turtas',
#  'Russia, Impilakhti',
#  'Russia, Sonkovo',
#  'Russia, Sovkhoza Imeni Lenina',
#  'Russia, Katav-Ivanovsk',
#  'Russia, Staraya Doroga',
#  'Russia, Belyashi (dzhazator)',
#  'Russia, Verkh-Biysk',
#  'Russia, Pindushi',
#  'Russia, Kizner (poselok)',
#  'Russia, Uvat',
#  'Russia, Zarechensk',
#  'Russia, Devyaternya',
#  'Russia, Yaransk',
#  'Russia, Trud-Rassvet',
#  'Russia, Kukmor',
#  'Russia, Tatarskoe Tyugulbaevo',
#  'Russia, Kulmetovo',
#  'Russia, Dolgy Ostrov',
#  'Russia, Olkhov Log',
#  'Russia, Pristen',
#  'Russia, Mednoe',
#  'Russia, Krasiki',
#  'Russia, Listvenny',
#  'Russia, Dmitriev',
#  'Russia, Iki Bukhus',
#  'Russia, Burlatskoe',
#  'Russia, Never',
#  'Russia, Verkhny Lomov',
#  'Russia, Smolensky',
#  'Russia, Vasilevo (poselok Urshelskiy)',
#  'Russia, Verkhny Avzyan',
#  'Russia, Bolshaya Vruda',
#  'Russia, Pola',
#  'Russia, Shamardan',
#  'Russia, Krepostnoy Zilair',
#  'Russia, Tatay-Khutor',
#  'Russia, Karachi',
#  'Russia, Sharan',
#  'Russia, Baltiysk',
#  'Russia, Ryndino',
#  'Russia, Lebyazhye',
#  'Russia, Cherkesovsky',
#  'Russia, Patkino',
#  'Russia, Staroscherbinovskaya',
#  'Russia, Korkino',
#  'Russia, Kadnikovsky',
#  'Russia, Chukaly',
#  'Russia, Yugydyag',
#  'Russia, Kandakovka',
#  'Russia, Severo-Vattsevskoe Lesnichestvo',
#  'Russia, Novaya Igirma',
#  'Russia, Voeykovo',
#  'Russia, Syukeevo',
#  'Russia, Bolshaya Pyssa',
#  'Russia, Komi Yb',
#  'Russia, Vyaz',
#  'Russia, Nizhegorodskaya',
#  'Russia, Tashla',
#  'Russia, Polevskoy',
#  'Russia, Borisoglebsk',
#  'Russia, Kalinovo',
#  'Russia, Chernigovka',
#  'Russia, Shadrinsk',
#  'Russia, Novokhopersky',
#  'Russia, Volotovo',
#  'Russia, Kurgan (derevnya)',
#  'Russia, Tetyushskoe',
#  'Russia, Vilovatovo',
#  'Russia, Palkino',
#  'Russia, Grafovka',
#  'Russia, Volskoe',
#  'Russia, Ivangorod',
#  'Russia, Dobrovolsk',
#  'Russia, Kazminskoe',
#  'Russia, Druzhba',
#  'Russia, Novoivanovka',
#  'Russia, Shandrovo',
#  'Russia, Rzhavki',
#  'Russia, Vasilchuki',
#  'Russia, Labozhskoe',
#  'Russia, Tyumensky',
#  'Russia, Ternovka',
#  'Russia, Lukoyanov',
#  'Russia, Ugez-Elga',
#  'Russia, Magnitny',
#  'Russia, Kochunovo',
#  'Russia, Podcherye',
#  'Russia, Lomigory',
#  'Russia, Khabarovsk (derevnya)',
#  'Russia, Novoe Shatkino',
#  'Russia, Lyuban (poselok)',
#  'Russia, Kholmina',
#  'Russia, Dorokhovo',
#  'Russia, Industria',
#  'Russia, Pavlovsk',
#  'Russia, Vysokovsk',
#  'Russia, Ostrolensky',
#  'Russia, Podgorensky',
#  'Russia, Bolshoe Boldino',
#  'Russia, Kulagino',
#  'Russia, Bor (derevnya)',
#  'Russia, Kirovsk',
#  'Russia, Vyazniki',
#  'Russia, Alexandria',
#  'Russia, Veliky Vrag',
#  'Russia, Mstikhino',
#  'Russia, Kugey',
#  'Russia, Yudikha',
#  'Russia, Pozdeevo',
#  'Russia, Dolgie Leski',
#  'Russia, Malysheva',
#  'Russia, Zimovniki',
#  'Russia, Savrukha',
#  'Russia, Seltso (derevnya)',
#  'Russia, Novotroitsk',
#  'Russia, Garazh',
#  'Russia, Mednogorsk',
#  'Russia, Taezhny',
#  'Russia, Gorkhon',
#  'Russia, Dimitrova',
#  'Russia, Talitsky Chamlyk',
#  'Russia, Aykino',
#  'Russia, Tuapse',
#  'Russia, Usinsk',
#  'Russia, Chesma',
#  'Russia, Karakol',
#  'Russia, Prokopyevskaya',
#  'Russia, Suleya',
#  'Russia, Avgustovka',
#  'Russia, Tovarkovo',
#  'Russia, Kopey-Kubovo',
#  'Russia, Pisarevka',
#  'Russia, Kungur (derevnya)',
#  'Russia, Khabary',
#  'Russia, Novye Paraty',
#  'Russia, Kremenchug',
#  'Russia, Debesy',
#  'Russia, Vityazevo',
#  'Russia, Ozerki',
#  'Russia, Adamovka',
#  'Russia, Uni',
#  'Russia, Brylino',
#  'Russia, Aparinsky',
#  'Russia, Novonagaevo',
#  'Russia, Petrograd',
#  'Russia, Muxinovo',
#  'Russia, Mogutovo',
#  'Russia, Kartaly',
#  'Russia, Nadezhda',
#  'Russia, Kavkaz',
#  'Russia, Emanzhelinka',
#  'Russia, Pechera',
#  'Russia, Sizyashur',
#  'Russia, Sernovodsk',
#  'Russia, Ust-Kamyshta',
#  'Russia, Kashin',
#  'Russia, Kyren',
#  'Russia, Keken-Vasilyevka',
#  'Russia, Verkhnechusovskie Gorodki',
#  'Russia, Krapivinsky',
#  'Russia, Parizh',
#  'Russia, Vityazi',
#  'Russia, Oktyabr',
#  'Russia, Zaslukhovye',
#  'Russia, Lakhoma',
#  'Russia, Dyakonovo',
#  'Russia, Balykcha',
#  'Russia, Dubovskoe',
#  'Russia, Bayderyakovo',
#  'Russia, Otradnoe',
#  'Russia, Makhonovo',
#  'Russia, Chuchkovo',
#  'Russia, Khushenga',
#  'Russia, Lokhovo',
#  'Russia, Nikulino',
#  'Russia, Smolenka',
#  'Russia, Ekaterinoslavka',
#  'Russia, Kholmskaya',
#  'Russia, Ostrovtsy',
#  'Russia, Makeevka',
#  'Russia, Bolsheromanovka',
#  'Russia, Dolgy Most',
#  'Russia, Krasny Partizan',
#  'Russia, Krasivy',
#  'Russia, Pravokubansky ',
#  'Russia, Olenino',
#  'Russia, Sakharovka',
#  'Russia, Repyevka',
#  'Russia, Nevidimka',
#  'Russia, Ploskoe',
#  'Russia, Troitsko-Pechorsk',
#  'Russia, Korzhevsky',
#  'Russia, Plotina',
#  'Russia, Agirtamak',
#  'Russia, Novoe Dubovoe',
#  'Russia, Turinskaya Sloboda',
#  'Russia, Ubinskoe',
#  'Russia, Smolenets',
#  'Russia, Soldatskaya Zh/d',
#  'Russia, Gorky',
#  'Russia, Urkarakh',
#  'Russia, Bima',
#  'Russia, Karla Marxa',
#  'Russia, Bizhbulyak',
#  'Russia, Polyarny',
#  'Russia, Krasavka',
#  'Russia, Timashevsk',
#  'Russia, Uporovo',
#  'Russia, Ukraina',
#  'Russia, Vershino-Shakhtaminsky',
#  'Russia, Reftinsky',
#  'Russia, Volot (poselok)',
#  'Russia, Abatskoe',
#  'Russia, Golitsyno',
#  'Russia, Petrovsk-Zabaykalsky',
#  'Russia, Muzhi',
#  'Russia, Novo-Nikolsk',
#  'Russia, Suzdal',
#  'Russia, Anna',
#  'Russia, Pochaevo',
#  'Russia, Lev Tolstoy',
#  'Russia, Poykovsky',
#  'Russia, Koshurnikovo',
#  'Russia, Meleuz',
#  'Russia, Kondratovo',
#  'Russia, Khomutovka',
#  'Russia, Vershina Tei',
#  'Russia, Kayakent',
#  'Russia, Novokayakent',
#  'Russia, Ust-Kachka',
#  'Russia, Barguzin',
#  'Russia, Cherepanova',
#  'Russia, Kysyl-Syr',
#  'Russia, Kosh-Agach',
#  'Russia, Ishkin',
#  'Russia, Odintsovo (derevnya)',
#  'Russia, Akhtubinsk',
#  'Russia, Bogorodskoe (selo)',
#  'Russia, Naginskoe',
#  'Russia, Nogliki',
#  'Russia, Deputatsky',
#  'Russia, Promyshlennaya ',
#  'Russia, 10 Km Avtodorogi Irkutsk-Shelekhovo Territoria',
#  'Russia, Belovo',
#  'Russia, Filippovka',
#  'Russia, Zlynka',
#  'Russia, Liskinskoe',
#  'Russia, Vyazma',
#  'Russia, Malaya Minusa',
#  'Russia, Akyulovo',
#  'Russia, Staromaryevka',
#  'Russia, Vizma',
#  'Russia, Fruktovaya',
#  'Russia, Khmyzovka',
#  'Russia, Smolyanka',
#  'Russia, Kosterevo',
#  'Russia, Novy Chechen',
#  'Russia, Novye Burasy',
#  'Russia, Altay (poselok)',
#  'Russia, Podolsk (selo)',
#  'Russia, Khormaly',
#  'Russia, Baxan',
#  'Russia, Kirzhach',
#  'Russia, Zhovnets',
#  'Russia, Kuleshovka',
#  'Russia, Korsakov',
#  'Russia, Chaltyr',
#  'Russia, Khilok',
#  'Russia, Ermolino',
#  'Russia, Cheboxary (derevnya)',
#  'Russia, Plyos',
#  'Russia, Bazarny Karabulak',
#  'Russia, Kishleevo',
#  'Russia, Orenburgskoe',
#  'Russia, Peleduy',
#  'Russia, Kuzino',
#  'Russia, Plavitsa',
#  'Russia, Kukshumy',
#  'Russia, Shakhtersk',
#  'Russia, Samagaltay',
#  'Russia, Chekhov (selo)',
#  'Russia, Krasnovka',
#  'Russia, Gubkin',
#  'Russia, Staraya Vichuga',
#  'Russia, Kuragan',
#  'Russia, Kinel',
#  'Russia, Volovo (selo)',
#  'Russia, Tes',
#  'Russia, Kordon',
#  'Russia, Kardonixkaya',
#  'Russia, Mamontovo',
#  'Russia, Scherbinka',
#  'Russia, Tokarevo',
#  'Russia, Olymsky',
#  'Russia, Gribanovo',
#  'Russia, Ossora',
#  'Russia, Shkola',
#  'Russia, Vladimir (selo)',
#  'Russia, Novopavlovsky',
#  'Russia, Mochily',
#  'Russia, Atyashevo (rabochy Poselok)',
#  'Russia, Grekhnev Pal',
#  'Russia, Kholmogory',
#  'Russia, Kusak',
#  'Russia, Navlya',
#  'Russia, Olonets',
#  'Russia, Shpankovo',
#  'Russia, Novobalakovo',
#  'Russia, Podozersky',
#  'Russia, Mechetinskaya',
#  'Russia, Schelkovo (derevnya)',
#  'Russia, Ovsyannikovo',
#  'Russia, Bolgar',
#  'Russia, Kashkino',
#  'Russia, Deyskoe',
#  'Russia, Nikolo-Berezovka',
#  'Russia, Russkoe Dobrino',
#  'Russia, Podosinki (poselok)',
#  'Russia, Tobolsk',
#  'Russia, Mokhsogollokh',
#  'Russia, Kargopol',
#  'Russia, Novopavlovsk',
#  'Russia, Krasnoe Znamya',
#  'Russia, Axarka',
#  'Russia, Parfino',
#  'Russia, Sug-Axy',
#  'Russia, Anos',
#  'Russia, Mezhdurechensk (pgt)',
#  'Russia, Voloshovo',
#  'Russia, Checheninskaya',
#  'Russia, Atyuryevo',
#  'Russia, Zagaynovo',
#  'Russia, Shlisselburg',
#  'Russia, Saskal',
#  'Russia, Borisoglebsky',
#  'Russia, Shakhty (poselok)',
#  'Russia, Nizhny Odes',
#  'Russia, Ordynskoe',
#  'Russia, Partizanskoe',
#  'Russia, Chetvertoe Otdelenie Psikhonevrologicheskogo Dispansera',
#  'Russia, Khurba',
#  'Russia, Kurkachi',
#  'Russia, Progress',
#  'Russia, Pushkinskie Gory',
#  'Russia, Linda (lindovsky S/s)',
#  'Russia, Kudara',
#  'Russia, Kulotino',
#  'Russia, Karabulak',
#  'Russia, Kommunar',
#  'Russia, Ostashkov',
#  'Russia, Kirovskoe',
#  'Russia, Aniva',
#  'Russia, Malaya Inya',
#  'Russia, Alkino-2',
#  'Russia, Zapolyarny',
#  'Russia, Igoshino',
#  'Russia, Yalta',
#  'Russia, Kulebaki',
#  'Russia, Gorodskoy Okrug Stavropol',
#  'Russia, Prokhorovka',
#  'Russia, Sibirtsevo',
#  'Russia, Zauralsky',
#  'Russia, Golyshmanovo (selo)',
#  'Russia, Zhilevo',
#  'Russia, Maryevka (otdelenie Sovkhoza Rossia)',
#  'Russia, Dzhangamakhi',
#  'Russia, Bykovo (poselok)',
#  'Russia, Znamenskoe',
#  'Russia, Ural',
#  'Russia, Onguday',
#  'Russia, Maslyansky',
#  'Russia, Yunost']

# %% [markdown]
# ## Геокодирование
#
# Преобразуем адреса магазинов из колонки ShopAddress в геокоординаты

# %%
geocoder = YandexGeocoder(api_key=API_KEY)

# %%
encoded_data = []
for adress in ch_data:
    s = geocoder.adress_to_geopoint(adress)
    print(adress, s)
    encoded_data.append(s)
# encoded_data
# Out:
# Russia, Kulunda [52.563758,78.946507]
# Russia, Spitsevka [45.120904,42.507013]
# Russia, Pokanaevka [56.514967,97.659915]
# Russia, Belorus [55.214671,34.184607]
# Russia, Pudost [59.616298,30.041693]
# Russia, Nema [57.505782,50.498479]
# Russia, Voronezhskoe Malanino [52.104453,39.329168]
# Russia, Rzhevskoe [55.081823,21.757394]
# Russia, Nekrasovskoe [57.674363,40.369004]
# Russia, Vakhrushi (pgt) [58.684661,50.026415]
# Russia, Slyudyanka [51.656501,103.718845]
# Russia, Duminichi [53.933216,35.105649]
# Russia, Sződ [61.698657,99.505405]
# Russia, Omutinskoe [56.475767,67.664674]
# Russia, Berezovo [54.045788,36.413821]
# Russia, Blagoveschensk [50.257456,127.534611]
# Russia, Zhilgorodok [51.997463,55.507378]
# Russia, Obvinsk [58.495365,54.850628]
# Russia, Sosnovy [59.904225,29.09221]
# Russia, Fedorovka (olkhovskoe S/p) [51.870924,58.041839]
# Russia, Terengul (selo) [53.827183,77.160908]
# Russia, Vorkuta [67.493504,64.050113]
# Russia, Nizhnyaya Ternovka [45.490682,42.326218]
# Russia, Cherdyn [60.401192,56.482166]
# Russia, Zakharov [48.164256,42.76358]
# Russia, Yutaza [54.590834,53.270015]
# Russia, Nizhneangarsk [55.788641,109.579094]
# Russia, Goryachy Klyuch [44.647406,39.127479]
# Russia, Lepley [54.309769,42.856278]
# Russia, Romodanovo [54.422062,45.332026]
# Russia, Lyskovo [56.021362,45.040971]
# Russia, Moshenskoe [58.511835,34.5853]
# Russia, Shinsha [56.422271,49.367168]
# Russia, Bolshoy [43.111725,132.350345]
# Russia, Galenki [44.047506,131.498904]
# Russia, Grunin Vorgol (selo) [52.855491,38.263542]
# Russia, Ostrovskoe (poselok) [57.805149,42.240635]
# Russia, Brusentsevo [52.437542,83.450481]
# Russia, Valday [57.98069,33.246406]
# Russia, Makushino [55.205029,67.248601]
# Russia, Slavyansk-Na-Kubani [45.260332,38.12822]
# Russia, Sandovo [58.462857,36.410946]
# Russia, Chernorechenskaya [44.236557,40.956386]
# Russia, Petropavlovsk [53.024265,158.643503]
# Russia, Yalanskoe [61.698657,99.505405]
# Russia, Iltyakovo [56.060494,64.171305]
# Russia, Zeleny [68.276257,54.278213]
# Russia, Golovchino [50.534347,35.801673]
# Russia, Lazarevo [56.824848,50.20014]
# Russia, Norma [56.337247,50.277449]
# Russia, Sudak [44.850532,34.976157]
# Russia, Panovy Kusty [52.088868,41.574624]
# Russia, Leningradskaya [46.320553,39.392886]
# Russia, Tigan-Bulyak [55.153447,50.252916]
# Russia, Zamzor [55.368799,98.651924]
# Russia, Lenki [52.935622,80.435384]
# Russia, Rasskazovo [52.653848,41.874302]
# Russia, Dneprovskoe [55.659079,33.907171]
# Russia, Kurovskoe [55.57718,38.923022]
# Russia, Kokorevka [52.586142,34.280906]
# Russia, Severo-Eniseysky [60.024576,93.367711]
# Russia, Vanino Pole [58.617559,29.853595]
# Russia, Tyubuk [56.048314,60.944601]
# Russia, Medet [54.184398,75.541398]
# Russia, Snytkino [52.600124,34.670362]
# Russia, Vtorovo [56.266927,40.799899]
# Russia, Molodogvardeysky [52.993998,49.935191]
# Russia, Kraskino [42.710613,130.783449]
# Russia, Kamenolomnya [45.247705,33.421847]
# Russia, Malaya Kamenka [48.33119,40.170764]
# Russia, Verkhnie Yuri [56.418592,52.533343]
# Russia, Usta [57.433045,45.66027]
# Russia, Elovo [61.698657,99.505405]
# Russia, Kantyshevo [43.228066,44.648453]
# Russia, Krasnaya Sloboda [56.431719,44.187257]
# Russia, Shali [43.153444,45.903956]
# Russia, Orlik [52.509825,99.821333]
# Russia, Kremyanoe [51.393241,35.076688]
# Russia, Dorgeli [42.666158,47.293668]
# Russia, Kurakino [52.545218,44.045369]
# Russia, Karinovka [52.019206,54.535346]
# Russia, Voyvozh [62.894311,54.967742]
# Russia, Pokachi [61.741652,75.599753]
# Russia, Bereznik (selo) [62.85192,42.719482]
# Russia, Stary Kryazhim [53.076976,46.182694]
# Russia, Iki-Burul [45.823769,44.646961]
# Russia, Rybachye [44.773626,34.596619]
# Russia, Ryatamak [54.079197,53.530967]
# Russia, Novaya Bryan [51.712172,108.258302]
# Russia, Tokyo [55.719815,37.694064]
# Russia, Novaya Chara [56.797753,118.271085]
# Russia, Khorinsk [52.161426,109.775107]
# Russia, Chulym [55.091263,80.963288]
# Russia, Ramon [51.911127,39.333049]
# Russia, Butrakhty [52.811675,89.988428]
# Russia, Toropets [56.495171,31.643686]
# Russia, Zaglyadino [53.55341,52.736605]
# Russia, Kazan (selo) [55.796127,49.106414]
# Russia, Ilka [51.721379,108.522541]
# Russia, Kuznets [44.418387,131.209395]
# Russia, Khonkholoy [51.129665,108.219045]
# Russia, Borovlyanka [52.633635,84.447584]
# Russia, Prichulymsky [56.389598,90.431396]
# Russia, Dzhaga [43.954404,42.554956]
# Russia, Azovsky [61.698657,99.505405]
# Russia, Antsiferovsky Bor [63.57228,39.01907]
# Russia, Verkhnyaya Zima [53.797289,101.782329]
# Russia, Tad-Magitl [42.550418,46.34935]
# Russia, Bolshekrepinskaya [47.597421,39.377534]
# Russia, Labytnangi [66.660883,66.37993]
# Russia, Konstantinovsky [43.398746,39.951881]
# Russia, Tsentralnaya Usadba Sovkhoza «serp I Molot» [53.198214,44.43857]
# Russia, Novichikha [52.205767,81.395216]
# Russia, Yurty [56.049269,97.63178]
# Russia, Shatki [55.188041,44.127987]
# Russia, Meshkovskaya [49.53989,40.993585]
# Russia, Zdvinsk [54.702484,78.661858]
# Russia, Karagush [53.295686,55.270294]
# Russia, Turgenevo (turgenevskoe S/p) [54.846187,46.337052]
# Russia, Sterlibashevo [53.439267,55.262353]
# Russia, Svatovo [45.812501,33.866396]
# Russia, Nikolskoe 1-E [55.369607,37.22526]
# Russia, Korolevo (krasavino G/p) [55.099711,35.929979]
# Russia, Orichi [58.40133,49.059729]
# Russia, Respublika [45.3892,33.993751]
# Russia, Khrustalny [55.614556,40.671045]
# Russia, Kalinka [52.983541,50.171403]
# Russia, Kesova Gora [57.57986,37.291223]
# Russia, Sevastopol (selo) [44.616495,33.525135]
# Russia, Armyansk [46.110727,33.691315]
# Russia, Tenki [55.43415,48.992651]
# Russia, Novye Gorki [59.613353,30.222057]
# Russia, Stupino [54.88628,38.078237]
# Russia, Lomonosov [59.91074,29.776466]
# Russia, Afanasyevka [54.639732,100.618687]
# Russia, Verbovsky [61.698657,99.505405]
# Russia, Zhizdra [53.7474,34.734187]
# Russia, Biryulinskogo Zverosovkhoza [55.977329,49.383652]
# Russia, Alexandrovskoe [60.426124,77.868475]
# Russia, Emeshevo [56.228721,46.350446]
# Russia, Krasnoe-Na-Volge [57.509427,41.239777]
# Russia, Ust-Koxa [50.268979,85.616076]
# Russia, Lyubim [58.362004,40.686882]
# Russia, Tugulym [57.058742,64.640486]
# Russia, Tavrichanka [43.324807,131.860044]
# Russia, Raychikhinsk [49.794114,129.411255]
# Russia, 44 Razezd [55.816778,70.608614]
# Russia, Vilyuysk [63.7549,121.623607]
# Russia, Sytomino [61.304161,71.29481]
# Russia, Emva [62.598375,50.886569]
# Russia, Kitovo [56.863842,41.299048]
# Russia, Izmalkovo [52.69211,37.957198]
# Russia, Luna [53.064392,54.54556]
# Russia, Prokoshevo [55.968514,44.455117]
# Russia, Gus-Zhelezny [55.055264,41.1591]
# Russia, Bobrov [51.097724,40.035604]
# Russia, Karievo [61.698657,99.505405]
# Russia, Tyulgan (stantsia) [52.341509,56.160147]
# Russia, Sovetskoe [47.502028,142.676237]
# Russia, Gorodskoy Okrug Gorod Yakutsk [62.027221,129.732178]
# Russia, Krasnoznamenka [60.406774,29.810332]
# Russia, Chuguny [56.065077,45.694675]
# Russia, Cherlak [54.151976,74.795671]
# Russia, Rovenki [49.914716,38.891985]
# Russia, Zheshart [62.095336,49.592259]
# Russia, Lebedevka [51.259149,35.175871]
# Russia, Babynino [54.391217,35.739492]
# Russia, Novopetrovskoe [55.994426,36.470406]
# Russia, Dzerzhinsky [55.630944,37.849616]
# Russia, Arabkaevo [61.698657,99.505405]
# Russia, Pyskor [59.482232,56.587736]
# Russia, Shabelskoe [46.851974,38.473137]
# Russia, Krush [55.992845,57.426287]
# Russia, Zheleznogorsk-Ilimsky [56.584848,104.114292]
# Russia, Donskoe [53.990491,38.295297]
# Russia, Konchinka [54.678281,38.157702]
# Russia, Alexandrov [59.917813,29.070677]
# Russia, Dolgovitsa [55.810926,31.308336]
# Russia, Zavety Ilicha [49.036349,140.268958]
# Russia, Bogoslovka [53.2129,44.806089]
# Russia, Novoorsk [51.382956,58.986337]
# Russia, Fershampenuaz [53.52044,59.810829]
# Russia, Pogadaevo [61.698657,99.505405]
# Russia, Molokovo [55.562154,37.863576]
# Russia, Zhigulevsky [54.092638,37.153036]
# Russia, Kurga [55.97466,59.318965]
# Russia, Gorodets [56.644822,43.47236]
# Russia, Volodarsk [56.223621,43.179977]
# Russia, Myski [53.712514,87.805747]
# Russia, Pizhanka [57.4576,48.540035]
# Russia, Mesker-Yurt [43.248459,45.912867]
# Russia, Krasnaya Gora [53.004447,31.603405]
# Russia, Matyushino [55.613611,49.02005]
# Russia, Alekhnovo [55.029136,36.318546]
# Russia, Yazhelbitsy [58.033634,32.973794]
# Russia, Vyazma-Bryanskaya [55.167231,34.34881]
# Russia, Sukhobezvodnoe (derevnya) [57.050083,44.895408]
# Russia, Sokol [59.460972,40.099986]
# Russia, Tatarsky Maloyaz [55.179724,58.155889]
# Russia, Asekeevo (selo) [53.574797,52.805479]
# Russia, Pchevzha [59.355278,32.351693]
# Russia, Ismaylovo [61.698657,99.505405]
# Russia, Novodzherelievskaya [45.774495,38.671278]
# Russia, Aserkhovo [55.945614,40.247327]
# Russia, Nizhnesortymsky [62.442807,71.765204]
# Russia, Perevalnoe [44.839911,34.322471]
# Russia, Gorki [59.613353,30.222057]
# Russia, Karpogory [64.000704,44.449548]
# Russia, Kulikovka [54.128847,45.237972]
# Russia, Teguldet [57.306081,88.166321]
# Russia, Glubokoe (kamennogorskoe G/p) [56.763396,60.912388]
# Russia, Lisya Gora [58.655354,28.831258]
# Russia, Padovka [52.468561,49.507745]
# Russia, Svetlogorsk [54.944218,20.156075]
# Russia, Chunsky [56.088298,99.6619]
# Russia, Snezhnogorsk [69.192567,33.242148]
# Russia, Natukhaevskaya [44.912132,37.569557]
# Russia, Duldug [41.768361,47.674428]
# Russia, Girvas [62.474038,33.678208]
# Russia, Kiev (derevnya) [44.966001,34.103588]
# Russia, Krasnoslobodsk [48.706788,44.563149]
# Russia, Tsarev [48.664509,45.372108]
# Russia, Novy Buyan [53.684617,50.0443]
# Russia, Knevitsy (poselok) [57.926411,32.226073]
# Russia, Novopanskoe [54.340061,39.06324]
# Russia, Razvilnoe [46.238784,41.289544]
# Russia, Pobeda [60.352206,29.440083]
# Russia, Pochtovoe [61.698657,99.505405]
# Russia, Snezhinsk [56.087303,60.732707]
# Russia, Urengoy [65.961949,78.372691]
# Russia, Sadovoe [51.640764,39.089462]
# Russia, Agidel [55.899043,53.933439]
# Russia, Moskovsky [56.826823,60.438203]
# Russia, Vokhtoga (pgt) [58.811684,41.046109]
# Russia, Selty [57.308964,52.138471]
# Russia, Kolpna [52.220003,37.034934]
# Russia, Yakshur-Bodya [57.184792,53.155444]
# Russia, Cherbi [51.88936,94.589276]
# Russia, Dolgoderevenskoe [55.344183,61.338638]
# Russia, Voznesenovka [51.080004,36.224097]
# Russia, Rovdino [64.227028,41.859785]
# Russia, Yaroslavl (derevnya) [57.626559,39.893813]
# Russia, Mindyak [54.018982,58.796146]
# Russia, Ladushkin [54.569121,20.172954]
# Russia, Krasnogorsky [55.813329,37.480768]
# Russia, Alexeevskoe [55.303248,50.107272]
# Russia, Starokucherbaevo [54.904235,54.857887]
# Russia, Sovkhoza «voronezhskiy» [51.504453,39.293505]
# Russia, Mudyuga  [63.775636,39.250305]
# Russia, Primorsk [60.366014,28.613561]
# Russia, Temyasovo [52.983823,58.125517]
# Russia, Karvudzhem [60.578154,50.784386]
# Russia, Sibir (poselok) [61.776586,79.762887]
# Russia, Linevo [55.377971,89.085855]
# Russia, Mogilev [66.361376,38.241309]
# Russia, Rukhtino [55.458531,58.377198]
# Russia, Pochekuevo [61.698657,99.505405]
# Russia, Sumkino [58.108773,68.325232]
# Russia, Klushino [56.032922,37.280354]
# Russia, Kurkino [53.426896,38.659268]
# Russia, Belyanka [50.464319,37.190998]
# Russia, Vostochny [79.411878,92.880366]
# Russia, Naryan-Mar [67.63805,53.006926]
# Russia, Adygeysk [44.884856,39.190567]
# Russia, Cheburenki [54.884695,72.519493]
# Russia, Mezhgorye [54.241604,57.973531]
# Russia, Fateevy [61.698657,99.505405]
# Russia, Shpalozavod [58.93207,81.555646]
# Russia, Amderma [69.760827,61.659454]
# Russia, Isetskoe [56.484685,65.323673]
# Russia, Chernoistochinsk [57.730254,59.875957]
# Russia, Ignatovka [53.94928,47.654853]
# Russia, Bobrujsk [54.508848,21.335195]
# Russia, Staroe Shaygovo [54.30409,44.468358]
# Russia, Gubkino [52.338906,36.648326]
# Russia, Nurma [56.70844,47.711348]
# Russia, Kyzyl-Tash [50.215783,87.941464]
# Russia, Shatunovo [53.899992,84.530264]
# Russia, Tenyaevo [61.698657,99.505405]
# Russia, Vedlozero [61.572115,32.83602]
# Russia, Filimonovo [56.206171,95.457399]
# Russia, Makaryev [57.880038,43.807764]
# Russia, Kishinevka [61.698657,99.505405]
# Russia, Solnechnogorsk-7 [56.215934,37.028062]
# Russia, Kulaevo [61.698657,99.505405]
# Russia, Rīga [58.436241,47.771517]
# Russia, Zelenodolsk [55.847048,48.492802]
# Russia, Grodno [53.93928,28.644499]
# Russia, Dubinino [55.625242,89.093562]
# Russia, Boloto [53.804037,36.32063]
# Russia, Druzhinino [56.787193,59.51292]
# Russia, Khumalag [43.240092,44.47612]
# Russia, Bardovo [56.674303,29.368424]
# Russia, Troitsa [61.944823,38.993315]
# Russia, Mamoshino [55.93181,36.421906]
# Russia, Vozrozhdenie (poselok) [55.674255,37.760018]
# Russia, Sorum [64.212112,69.039383]
# Russia, Malyachkino [53.390057,48.591679]
# Russia, Birsk [55.417531,55.530716]
# Russia, Velikie Suki [56.343703,30.515671]
# Russia, Dzhida [50.683142,106.180022]
# Russia, Vargashi (rp) [55.375496,65.815761]
# Russia, Chernyakhovsk [54.630706,21.819503]
# Russia, Poedugi [61.698657,99.505405]
# Russia, Khatanga [71.980467,102.483419]
# Russia, Ledmozero [64.250683,32.028677]
# Russia, Tereben (derevnya) [53.431312,35.266816]
# Russia, Shovkra [42.140493,47.12597]
# Russia, Asino [56.997519,86.153906]
# Russia, Kamyshinsky [50.166508,45.312218]
# Russia, Kurlovo [55.454973,40.611208]
# Russia, Dedinovo [55.057131,39.128251]
# Russia, Tatischevo [55.277554,36.345199]
# Russia, Shingak-Kul [54.38503,55.207691]
# Russia, Putilkovo [55.86743,37.395491]
# Russia, Shaygino [57.767491,46.860159]
# Russia, Chuvashskoe Drozhzhanoe [54.707848,47.525864]
# Russia, Ytyk-Kyuel [62.360667,133.559899]
# Russia, Tubinsky [57.64347,103.283198]
# Russia, Gurulevo [52.402061,107.923383]
# Russia, Novye Shimkusy [55.156765,47.766325]
# Russia, Gryazovets [58.880756,40.254343]
# Russia, Novorossiysky [44.723771,37.768813]
# Russia, Zudilovo [53.487284,83.887628]
# Russia, Tyret 1-Ya [53.669086,102.315955]
# Russia, Novoyangelka [53.20042,58.918909]
# Russia, Krasnaya Gorka (selo) [55.386998,46.108457]
# Russia, Emetsk [63.470916,41.777868]
# Russia, Kamensk-Uralsky Gorodskoy Okrug [56.396787,61.952251]
# Russia, Nikolo-Pavlovskoe [57.786587,60.053194]
# Russia, Tatarstan [55.350341,50.911013]
# Russia, Kamyshenka [52.010481,84.392328]
# Russia, Shebalov [51.755768,43.758878]
# Russia, Kingisepp [59.378053,28.601209]
# Russia, Letnyaya Stavka [45.42635,43.443551]
# Russia, Sumy [54.811051,80.43851]
# Russia, Andreevo [43.097277,132.335316]
# Russia, Palekh [56.801799,41.852527]
# Russia, Bolokhovo [54.082113,37.826799]
# Russia, Vizhay [60.932045,57.869632]
# Russia, Navoloki [57.470593,41.957774]
# Russia, Divnogorsk [55.957726,92.380148]
# Russia, Kharkovskoe [43.475322,46.334483]
# Russia, Gorodki [52.46534,56.134869]
# Russia, Russky Kameshkir [52.860863,46.093195]
# Russia, Tolstoy-Yurt [43.445385,45.777976]
# Russia, Bystry Istok [52.371298,84.389939]
# Russia, Rzhaxa [61.698657,99.505405]
# Russia, Novolisino (fornosovskoe G/p) [59.563929,30.766921]
# Russia, Kireevsk [53.934949,37.928542]
# Russia, Kola [68.878221,33.025232]
# Russia, Molodi [55.27439,37.511697]
# Russia, Volot (derevnya) [57.927807,30.70677]
# Russia, Fokino [53.455436,34.415923]
# Russia, Topsa [62.597998,43.629269]
# Russia, Murzitsy [55.449633,42.482453]
# Russia, Charomskoe [59.342336,38.617873]
# Russia, Barvikha (poselok) [56.263162,39.153476]
# Russia, Sirius [43.404857,39.959453]
# Russia, Beloyarka [55.415043,83.197883]
# Russia, Kandry [54.55277,54.107928]
# Russia, Tungor [53.388049,142.955478]
# Russia, Kchun-Kazmalyar [41.761925,48.488068]
# Russia, Malaya Glushitsa [52.437558,50.204012]
# Russia, Tunoshna [57.543052,40.123441]
# Russia, Kamyshi [51.813311,36.276729]
# Russia, Verkh-Chita [52.233105,113.509853]
# Russia, Podberezye [58.700875,31.401141]
# Russia, Kursk (derevnya) [51.730846,36.193015]
# Russia, Novopokrovskaya [45.953831,40.707004]
# Russia, Kuznechnoe [61.124369,29.880455]
# Russia, Botulu [64.138143,119.776868]
# Russia, Krasnoe Seltso [53.373966,34.105923]
# Russia, Sukhoroslovo [57.490494,56.551139]
# Russia, Polovinnoe [54.788933,65.98786]
# Russia, Nartan [43.505512,43.701673]
# Russia, Bym [57.433302,56.331402]
# Russia, Kuznetsovka [56.087248,101.243591]
# Russia, Sokolskoe [61.698657,99.505405]
# Russia, Mistsevo (poselok) [55.640635,39.081126]
# Russia, Limbyayakha [66.017944,78.086909]
# Russia, Bobrovsky [51.664088,39.267778]
# Russia, Kaluga (selo) [54.513678,36.261341]
# Russia, Shexna (pgt) [59.20654,38.501353]
# Russia, Severomorsk-3 [68.884991,33.734227]
# Russia, Petergof [59.881227,29.906775]
# Russia, Ukhovsky [61.698657,99.505405]
# Russia, Malye Derbety [47.951388,44.676219]
# Russia, Rogovsky [61.698657,99.505405]
# Russia, Mordovskaya Polyana [53.954324,42.830586]
# Russia, Izberbash [42.565148,47.871087]
# Russia, Sura [53.88782,45.769325]
# Russia, Mokushino [57.044722,43.84614]
# Russia, Dedenevo [56.244255,37.52015]
# Russia, Zaigraevo [51.835054,108.267473]
# Russia, Meteor [64.660518,140.868664]
# Russia, Korenovsk [45.462742,39.448033]
# Russia, Maly Ray [43.538563,39.820888]
# Russia, Mikun (derevnya) [62.356493,50.082532]
# Russia, Mirgorodsky [55.538718,37.567267]
# Russia, Meschegarovo [55.422349,58.207363]
# Russia, Gelendzhik [44.561012,38.077115]
# Russia, Ladva-Vetka [61.36194,34.449142]
# Russia, Verkhovye [52.808594,37.235474]
# Russia, Primorsky [45.04198,134.709375]
# Russia, Dyektiek [61.698657,99.505405]
# Russia, Medyana [55.481148,46.161467]
# Russia, Kichmenga [60.051198,45.599894]
# Russia, Galashki [43.080798,44.984297]
# Russia, Kamyshlov [56.843988,62.707464]
# Russia, Tixi [61.698657,99.505405]
# Russia, Stepankovo [56.065424,37.815292]
# Russia, Liman [45.781843,47.223824]
# Russia, Grayvoron [50.486275,35.66583]
# Russia, Romny [50.719802,129.291447]
# Russia, Yamanchurino [54.969331,47.9594]
# Russia, Platonovka [52.716053,41.956705]
# Russia, Kachelay [53.933502,45.658689]
# Russia, Alexeevsky [52.610669,51.24338]
# Russia, Novokhopersk [51.100388,40.718826]
# Russia, Aznakaevo [54.858233,53.079923]
# Russia, Pervomayskoe [60.358241,29.738269]
# Russia, Starye Aybesi [54.95081,47.044484]
# Russia, Novocheboxarsk [56.108738,47.476807]
# Russia, Kimovsk [53.972149,38.533063]
# Russia, Lazo [45.87507,133.649533]
# Russia, Novy Byt [55.974373,41.622433]
# Russia, Uvelsky [61.698657,99.505405]
# Russia, Proletarsky [55.641671,37.655616]
# Russia, Biryusinsk [55.962438,97.813302]
# Russia, Krutikha [53.965057,81.208348]
# Russia, Lek (poselok) [66.983281,61.079888]
# Russia, Kramatorsk [61.698657,99.505405]
# Russia, Ozernoe [61.698657,99.505405]
# Russia, Sever [64.475671,39.948251]
# Russia, Otradovka [46.663572,39.094178]
# Russia, Zaozersk [60.482992,60.064854]
# Russia, Kyylud [56.865909,52.458154]
# Russia, Ulu-Yul [57.710109,85.792362]
# Russia, Ungun Teryachi [47.819003,44.711712]
# Russia, Sadovy [44.44889,41.498717]
# Russia, Alexandrovsky Zavod [50.924393,117.935547]
# Russia, Lavrovskaya [57.569595,27.534028]
# Russia, Oykha [53.865393,92.57537]
# Russia, Kalnibolotskaya [46.002363,40.453105]
# Russia, Keres [61.868212,52.670076]
# Russia, Chicha [54.745007,78.580525]
# Russia, Lyuban [59.349301,31.24858]
# Russia, Slavgorodskoe [53.022363,78.645419]
# Russia, Chontaul [43.303646,46.859701]
# Russia, Alexandrovka [61.698657,99.505405]
# Russia, Novy Vasyugan [58.577176,76.499164]
# Russia, Mechetlino [55.364256,58.005916]
# Russia, Chelkasy [55.702749,47.911771]
# Russia, Narovchatka [53.285804,59.092464]
# Russia, Sibirskie Ogni [51.912221,83.537671]
# Russia, Bavleny (selo) [56.393454,39.559281]
# Russia, Chernyshevsky [44.73369,37.735054]
# Russia, Meneuztamak [53.707845,54.522788]
# Russia, Koslan [63.456248,48.894142]
# Russia, Novorossiyskoe [44.329046,38.699198]
# Russia, Kiritsy [54.286508,40.34961]
# Russia, Gladyshevo [58.396016,42.401254]
# Russia, Chazhemto [58.060231,82.826753]
# Russia, Goritsy [57.14925,36.734528]
# Russia, Revda 3-Ya [68.008189,34.388345]
# Russia, Kuluevo [55.224767,60.599648]
# Russia, Ikovka [55.607504,64.942086]
# Russia, Tsipya [56.525271,50.29961]
# Russia, Chernyakino [54.412569,63.056083]
# Russia, Nes [66.600876,44.678914]
# Russia, Likino-Dulevo [55.707086,38.958712]
# Russia, Velikaya Niva [62.357783,35.216447]
# Russia, Argayash [55.490728,60.877695]
# Russia, Chulman [56.840587,124.904641]
# Russia, Shokhovo (derevnya) [55.503798,35.63146]
# Russia, Khrenovoe [51.118834,40.283997]
# Russia, Kuchkovo [56.638828,35.251176]
# Russia, Koygorodok [60.445227,50.999838]
# Russia, Sverdlovskaya [58.58676,61.530761]
# Russia, Shagaevo [61.698657,99.505405]
# Russia, Shorchekasy [55.976236,47.472962]
# Russia, Kyzyl-Ozek [51.892383,85.995866]
# Russia, Cheremukhovo [53.800735,38.815826]
# Russia, Souzga [51.887075,85.851264]
# Russia, Ozerki (stantsia) [54.63239,20.889091]
# Russia, Shagonar [51.534711,92.919981]
# Russia, Kamensk-Shakhtinsky [48.323133,40.269534]
# Russia, Sherbakul [54.629299,72.391348]
# Russia, Lodeyka [60.696094,45.759624]
# Russia, Bolshaya Glushitsa [52.392769,50.471907]
# Russia, Samut Sakhon [61.698657,99.505405]
# Russia, Solikamsk [59.649193,56.770391]
# Russia, Velikooktyabrsky [57.429983,33.822047]
# Russia, 1 Km Avtodorogi Irkutsk-Markova Territoria [55.389668,38.202331]
# Russia, Grabovo [53.377237,45.063321]
# Russia, Khromtsovo [57.221958,40.963393]
# Russia, Nezlobnaya [44.116845,43.408517]
# Russia, Dzerzhinskoe [56.520057,84.839051]
# Russia, Zilgi [43.230312,44.525329]
# Russia, Leontyevo [55.061307,38.286557]
# Russia, Stary Oskol [51.297974,37.833231]
# Russia, Bakhtigildino [55.09016,47.188134]
# Russia, Korolyov [55.918953,37.815211]
# Russia, Timiryazevsky [55.832576,37.538997]
# Russia, Simferopol [44.948237,34.100327]
# Russia, Siva [58.381402,54.379471]
# Russia, Aramil 2 [56.700276,60.828647]
# Russia, Luchshevo [53.835414,86.907315]
# Russia, Barun [51.145738,90.578945]
# Russia, Vyshkovo [57.18269,35.635377]
# Russia, Severomuysk [56.171092,113.575798]
# Russia, Dobryanka [58.468068,56.403986]
# Russia, Tabory [58.518853,64.550547]
# Russia, Artyshta [54.11802,86.272655]
# Russia, Elegest [51.362692,93.960823]
# Russia, Fominki [55.964186,42.367917]
# Russia, Ilino [57.386494,38.080474]
# Russia, Santa Marta [54.983799,37.885845]
# Russia, Dzhabyk [53.162607,59.965528]
# Russia, Kitay Gora [58.351149,36.762807]
# Russia, Italmas [56.915859,53.476098]
# Russia, Farn [43.18158,44.500877]
# Russia, Novy Miass [55.315483,60.514695]
# Russia, Batagay [67.656157,134.636099]
# Russia, Tolyen [57.707734,53.694685]
# Russia, Borisoglebskoe [55.8621,49.123554]
# Russia, Imeni Sverdlova [59.798149,30.636603]
# Russia, Cherkessky [44.223084,42.062688]
# Russia, Manushkino [55.117963,37.459298]
# Russia, Gagarino [56.010629,69.379584]
# Russia, Khakurinokhabl [45.019271,40.23635]
# Russia, Sababash [56.032932,50.606484]
# Russia, Baley [51.582284,116.637948]
# Russia, Arya [57.488898,45.974555]
# Russia, Srednesibirsky [53.74257,83.644885]
# Russia, Vozhega [60.473691,40.212455]
# Russia, Konevo [56.455483,43.202632]
# Russia, Kiknur [57.306178,47.205112]
# Russia, Domna [51.896152,113.156276]
# Russia, Zueva [56.474723,85.043957]
# Russia, Pleshanovo [52.845213,53.488926]
# Russia, Khonuu [66.454762,143.221406]
# Russia, Vostok [46.447273,135.825729]
# Russia, Teykovo [56.85436,40.535471]
# Russia, Dergachi [51.236028,48.762772]
# Russia, Krapivensky-1 [54.083782,32.73239]
# Russia, Sannikovo [53.343635,83.97118]
# Russia, Narmonka [55.490294,49.295851]
# Russia, Urgala [55.553401,59.492008]
# Russia, Novaya Maka [41.771314,48.358782]
# Russia, Ulanovka [56.399348,86.102909]
# Russia, Mshinskaya [59.015771,29.939339]
# Russia, Kyzylbay [56.349046,64.265233]
# Russia, Karsun [54.200786,46.980766]
# Russia, Novoagansk [61.947091,76.662505]
# Russia, Letnik [46.00262,41.267859]
# Russia, Stary Nadym [65.606874,72.694529]
# Russia, Novy Ray [54.943928,43.323437]
# Russia, Tatil [41.993094,47.987517]
# Russia, Narimanov [46.689553,47.854405]
# Russia, Shatura [55.577577,39.544575]
# Russia, Kadryakovo [56.140274,53.140559]
# Russia, Iogach [51.784448,87.256849]
# Russia, Mayak [54.561072,75.060216]
# Russia, Chernokozovo [43.671038,45.360619]
# Russia, Oryol (derevnya) [52.970756,36.064358]
# Russia, Ardatov [54.848898,46.23627]
# Russia, Grachev [49.411321,41.519306]
# Russia, Masalovka [53.120032,35.026508]
# Russia, Lukyanovka [54.314938,73.055778]
# Russia, Povarkasy [55.714054,47.513306]
# Russia, Protichka [45.380275,38.073665]
# Russia, Chechen-Aul [43.19399,45.776233]
# Russia, Pushka [69.378742,33.481217]
# Russia, Raduzhny [62.135232,77.464]
# Russia, Chutay [56.511883,50.514137]
# Russia, Konstantinovo [55.334204,38.624988]
# Russia, Vyatskie Polyany [56.229491,51.032851]
# Russia, Aminevo [54.197289,60.120523]
# Russia, Semenov [49.594904,39.866002]
# Russia, Starobelsk [61.698657,99.505405]
# Russia, Vedenyapino [53.774217,43.350908]
# Russia, Kamenetsky [61.698657,99.505405]
# Russia, Kashary [49.037512,41.007455]
# Russia, Taman [45.215612,36.718413]
# Russia, Vladivostoxkoe Shosse 40 Km [63.308311,31.559154]
# Russia, Kistendey [52.101582,43.664932]
# Russia, Mazurka [51.273182,42.563975]
# Russia, Vasilyevo [55.830528,48.681089]
# Russia, Yarensk [62.168781,49.089103]
# Russia, Kalashnikovo [57.279735,35.224541]
# Russia, Staroyuryevo [53.320232,40.695335]
# Russia, Shadchi [55.924941,51.274031]
# Russia, Kodinsk [58.603412,99.179712]
# Russia, Karpinsk [59.766633,60.001074]
# Russia, Chudinovo [56.240293,42.067404]
# Russia, Stary Kurdym [56.249782,55.489537]
# Russia, Sretensk [52.243661,117.696029]
# Russia, Usmanovo [54.134239,56.639255]
# Russia, Teploozersk [49.010945,131.883688]
# Russia, Skopin [53.82359,39.54939]
# Russia, Mamakan [57.81762,114.012352]
# Russia, Olkhovka [56.728781,54.018932]
# Russia, Erzin [50.260825,95.159338]
# Russia, Rudovka [53.100178,42.383153]
# Russia, Dinskaya [45.218577,39.223068]
# Russia, Kamennomostsky [44.296028,40.183475]
# Russia, Priobye [62.549286,65.648198]
# Russia, Krasnogoryevka [55.57662,94.828326]
# Russia, Buinsk [54.964158,48.290151]
# Russia, Elektrougli [55.716818,38.214772]
# Russia, Kushva [58.282571,59.764682]
# Russia, Yartsevo-Surmenevo [55.072566,32.980577]
# Russia, Suzun [53.789476,82.312728]
# Russia, Urukh [43.292826,44.027438]
# Russia, Tyaterbash [53.491516,55.212901]
# Russia, Goryachinsk [52.985569,108.300091]
# Russia, Biserovo [59.06878,53.260377]
# Russia, Gorokhovets [56.2017,42.691203]
# Russia, Bodaybo [57.847975,114.199867]
# Russia, Dnipro (Dnipropetrovsk) [49.174668,32.959484]
# Russia, Kucherbaevo [61.698657,99.505405]
# Russia, Kotelnich [58.305095,48.346313]
# Russia, Novokizhinginsk [51.621902,109.600358]
# Russia, Bokhan [53.154006,103.78117]
# Russia, Sukaevka [61.698657,99.505405]
# Russia, Turtas [58.940651,69.144549]
# Russia, Impilakhti [61.670838,31.15776]
# Russia, Sonkovo [57.780987,37.165459]
# Russia, Sovkhoza Imeni Lenina [55.584461,37.735422]
# Russia, Katav-Ivanovsk [54.753513,58.205836]
# Russia, Staraya Doroga [54.95291,33.589167]
# Russia, Belyashi (dzhazator) [49.70627,87.425148]
# Russia, Verkh-Biysk [52.036987,87.090544]
# Russia, Pindushi [62.916878,34.578491]
# Russia, Kizner (poselok) [56.286348,51.50762]
# Russia, Uvat [59.142253,68.89647]
# Russia, Zarechensk [66.681577,31.432788]
# Russia, Devyaternya [56.200914,53.395232]
# Russia, Yaransk [57.304233,47.885855]
# Russia, Trud-Rassvet [50.368971,42.905038]
# Russia, Kukmor [56.186599,50.89399]
# Russia, Tatarskoe Tyugulbaevo [54.802516,49.668319]
# Russia, Kulmetovo [55.175195,58.709845]
# Russia, Dolgy Ostrov [69.268475,59.060295]
# Russia, Olkhov Log [50.567268,39.263888]
# Russia, Pristen [51.236366,36.696521]
# Russia, Mednoe [56.92981,35.47916]
# Russia, Krasiki [57.409229,54.930156]
# Russia, Listvenny [60.817638,28.939398]
# Russia, Dmitriev [55.834633,37.92547]
# Russia, Iki Bukhus [48.042571,45.218766]
# Russia, Burlatskoe [45.056696,43.643202]
# Russia, Never [53.976698,124.139869]
# Russia, Verkhny Lomov [53.465236,43.550334]
# Russia, Smolensky [55.748275,37.58031]
# Russia, Vasilevo (poselok Urshelskiy) [54.878816,44.743027]
# Russia, Verkhny Avzyan [53.524311,57.532081]
# Russia, Bolshaya Vruda [59.40625,29.241393]
# Russia, Pola [57.936241,31.830724]
# Russia, Shamardan [58.021191,52.152682]
# Russia, Krepostnoy Zilair [52.41975,57.681076]
# Russia, Tatay-Khutor [43.041961,46.484887]
# Russia, Karachi [57.711926,50.091722]
# Russia, Sharan [54.820052,54.005781]
# Russia, Baltiysk [54.643775,19.894477]
# Russia, Ryndino [55.079318,46.310641]
# Russia, Lebyazhye [57.413626,49.528739]
# Russia, Cherkesovsky [55.803919,37.731263]
# Russia, Patkino [55.521246,38.153148]
# Russia, Staroscherbinovskaya [46.633433,38.666787]
# Russia, Korkino [54.892493,61.393049]
# Russia, Kadnikovsky [60.320013,40.26497]
# Russia, Chukaly [54.714911,46.291866]
# Russia, Yugydyag [61.629659,54.943604]
# Russia, Kandakovka [55.599026,58.47887]
# Russia, Severo-Vattsevskoe Lesnichestvo [54.050446,36.576623]
# Russia, Novaya Igirma [57.145085,103.927299]
# Russia, Voeykovo [59.951903,30.706689]
# Russia, Syukeevo [55.107751,49.01554]
# Russia, Bolshaya Pyssa [64.166456,48.828125]
# Russia, Komi Yb [61.273215,50.576444]
# Russia, Vyaz [56.611246,29.654492]
# Russia, Nizhegorodskaya [56.595648,44.279559]
# Russia, Tashla [51.768076,52.743055]
# Russia, Polevskoy [56.495802,60.236307]
# Russia, Borisoglebsk [51.366308,42.075183]
# Russia, Kalinovo [50.497639,38.435488]
# Russia, Chernigovka [44.335693,132.585012]
# Russia, Shadrinsk [56.087042,63.629747]
# Russia, Novokhopersky [51.081057,41.56804]
# Russia, Volotovo [50.933249,38.146725]
# Russia, Kurgan (derevnya) [55.441004,65.341118]
# Russia, Tetyushskoe [54.31519,48.023118]
# Russia, Vilovatovo [56.176208,46.604435]
# Russia, Palkino [57.540656,28.009012]
# Russia, Grafovka [50.404896,36.740215]
# Russia, Volskoe [57.778712,37.271514]
# Russia, Ivangorod [59.37649,28.219712]
# Russia, Dobrovolsk [54.769902,22.504172]
# Russia, Kazminskoe [61.698657,99.505405]
# Russia, Druzhba [44.193425,42.014817]
# Russia, Novoivanovka [46.519967,40.291498]
# Russia, Shandrovo [55.012212,44.30729]
# Russia, Rzhavki [56.013039,37.222008]
# Russia, Vasilchuki [52.273373,78.951322]
# Russia, Labozhskoe [60.842669,31.460636]
# Russia, Tyumensky [55.812024,37.738018]
# Russia, Ternovka [51.685473,41.592222]
# Russia, Lukoyanov [55.032702,44.493358]
# Russia, Ugez-Elga [56.395058,49.920934]
# Russia, Magnitny [52.433567,35.557134]
# Russia, Kochunovo [55.4425,44.982231]
# Russia, Podcherye [63.93798,57.560459]
# Russia, Lomigory [52.135851,37.827976]
# Russia, Khabarovsk (derevnya) [48.480229,135.071917]
# Russia, Novoe Shatkino [52.913303,46.224906]
# Russia, Lyuban (poselok) [59.349301,31.24858]
# Russia, Kholmina [56.162772,33.543659]
# Russia, Dorokhovo [55.550932,36.376164]
# Russia, Industria [55.510935,47.538099]
# Russia, Pavlovsk [50.453624,40.130439]
# Russia, Vysokovsk [56.320248,36.551236]
# Russia, Ostrolensky [53.684431,59.724797]
# Russia, Podgorensky [50.403242,39.637111]
# Russia, Bolshoe Boldino [55.00359,45.310861]
# Russia, Kulagino [51.888081,53.650766]
# Russia, Bor (derevnya) [56.356522,44.064575]
# Russia, Kirovsk [59.87533,30.981457]
# Russia, Vyazniki [56.247026,42.158862]
# Russia, Alexandria [55.323956,37.751062]
# Russia, Veliky Vrag [56.151457,44.23962]
# Russia, Mstikhino [54.558676,36.126701]
# Russia, Kugey [46.8788,39.316385]
# Russia, Yudikha [53.433543,81.942551]
# Russia, Pozdeevo [61.698657,99.505405]
# Russia, Dolgie Leski [53.239897,37.645088]
# Russia, Malysheva [57.116781,61.395116]
# Russia, Zimovniki [47.145376,42.46772]
# Russia, Savrukha [53.615503,51.682234]
# Russia, Seltso (derevnya) [53.373966,34.105923]
# Russia, Novotroitsk [51.196355,58.299683]
# Russia, Garazh [55.972554,32.28546]
# Russia, Mednogorsk [51.403446,57.582944]
# Russia, Taezhny [58.071399,97.31533]
# Russia, Gorkhon [51.561566,108.786547]
# Russia, Dimitrova [45.669606,38.820264]
# Russia, Talitsky Chamlyk [52.040638,40.547616]
# Russia, Aykino [62.224318,49.991883]
# Russia, Tuapse [44.095245,39.073382]
# Russia, Usinsk [65.994148,57.55701]
# Russia, Chesma [53.813081,60.653224]
# Russia, Karakol [51.611668,86.264624]
# Russia, Prokopyevskaya [58.975534,53.12015]
# Russia, Suleya [55.133447,58.879608]
# Russia, Avgustovka [52.251689,50.740243]
# Russia, Tovarkovo [54.67724,35.942735]
# Russia, Kopey-Kubovo [54.527124,54.368772]
# Russia, Pisarevka [49.884253,40.181328]
# Russia, Kungur (derevnya) [57.42881,56.944215]
# Russia, Khabary [53.623797,79.53989]
# Russia, Novye Paraty [55.983534,48.657032]
# Russia, Kremenchug [51.453885,39.102299]
# Russia, Debesy [61.698657,99.505405]
# Russia, Vityazevo [44.988387,37.256953]
# Russia, Ozerki [54.63239,20.889091]
# Russia, Adamovka [51.51975,59.93582]
# Russia, Uni [57.755281,51.48942]
# Russia, Brylino [56.059916,64.940362]
# Russia, Aparinsky [47.660278,40.919797]
# Russia, Novonagaevo [61.698657,99.505405]
# Russia, Petrograd [59.938955,30.315644]
# Russia, Muxinovo [61.698657,99.505405]
# Russia, Mogutovo [53.153255,52.152799]
# Russia, Kartaly [53.053308,60.639462]
# Russia, Nadezhda [69.327769,87.964973]
# Russia, Kavkaz [43.46757,43.840202]
# Russia, Emanzhelinka [54.801691,61.2971]
# Russia, Pechera [59.209336,54.280458]
# Russia, Sizyashur [56.644569,52.681844]
# Russia, Sernovodsk [53.921982,51.255759]
# Russia, Ust-Kamyshta [53.351703,90.707368]
# Russia, Kashin [57.361939,37.607745]
# Russia, Kyren [51.682491,102.13057]
# Russia, Keken-Vasilyevka [53.714683,54.715701]
# Russia, Verkhnechusovskie Gorodki [58.169544,57.106073]
# Russia, Krapivinsky [55.766754,37.61689]
# Russia, Parizh [53.297914,60.097095]
# Russia, Vityazi [55.011903,32.301828]
# Russia, Oktyabr [57.824944,37.388448]
# Russia, Zaslukhovye [58.897849,30.604461]
# Russia, Lakhoma [61.962868,45.918293]
# Russia, Dyakonovo [51.640764,35.895879]
# Russia, Balykcha [51.286793,87.719077]
# Russia, Dubovskoe [54.663302,22.115714]
# Russia, Bayderyakovo [53.452422,48.545398]
# Russia, Otradnoe [59.77409,30.794553]
# Russia, Makhonovo [52.907498,39.765741]
# Russia, Chuchkovo [54.271484,41.444997]
# Russia, Khushenga [51.433586,110.922821]
# Russia, Lokhovo [53.055955,102.891407]
# Russia, Nikulino [58.813665,56.75794]
# Russia, Smolenka [52.142799,113.513033]
# Russia, Ekaterinoslavka [50.372315,129.119284]
# Russia, Kholmskaya [44.848046,38.389234]
# Russia, Ostrovtsy [55.591345,37.992646]
# Russia, Makeevka [61.698657,99.505405]
# Russia, Bolsheromanovka [52.993917,78.860054]
# Russia, Dolgy Most [69.268475,59.060295]
# Russia, Krasny Partizan [51.378318,83.580952]
# Russia, Krasivy [42.833095,43.659075]
# Russia, Pravokubansky  [43.906856,41.883214]
# Russia, Olenino [56.20868,33.479393]
# Russia, Sakharovka [55.310473,50.290088]
# Russia, Repyevka [53.783688,46.387169]
# Russia, Nevidimka [58.001027,57.891946]
# Russia, Ploskoe [56.307022,92.76212]
# Russia, Troitsko-Pechorsk [62.712213,56.198586]
# Russia, Korzhevsky [61.698657,99.505405]
# Russia, Plotina [53.920386,41.879279]
# Russia, Agirtamak [54.626177,53.766191]
# Russia, Novoe Dubovoe [52.30747,39.212855]
# Russia, Turinskaya Sloboda [57.618062,64.387467]
# Russia, Ubinskoe [55.299542,79.685893]
# Russia, Smolenets [64.926962,45.748628]
# Russia, Soldatskaya Zh/d [57.569518,30.858145]
# Russia, Gorky [58.438611,49.176905]
# Russia, Urkarakh [42.164737,47.632566]
# Russia, Bima [55.617627,49.502742]
# Russia, Karla Marxa [45.24061,39.075143]
# Russia, Bizhbulyak [53.692594,54.269616]
# Russia, Polyarny [69.197402,33.437235]
# Russia, Krasavka [51.166911,43.416862]
# Russia, Timashevsk [45.6142,38.933973]
# Russia, Uporovo [56.311062,66.2718]
# Russia, Ukraina [54.107448,35.244933]
# Russia, Vershino-Shakhtaminsky [51.293519,117.894934]
# Russia, Reftinsky [57.088988,61.680142]
# Russia, Volot (poselok) [57.927807,30.70677]
# Russia, Abatskoe [56.286438,70.44902]
# Russia, Golitsyno [55.615949,36.987126]
# Russia, Petrovsk-Zabaykalsky [51.276354,108.853579]
# Russia, Muzhi [65.403127,64.70927]
# Russia, Novo-Nikolsk [43.849947,131.865066]
# Russia, Suzdal [56.419333,40.448757]
# Russia, Anna [51.485932,40.426317]
# Russia, Pochaevo [61.698657,99.505405]
# Russia, Lev Tolstoy [53.212091,39.447099]
# Russia, Poykovsky [60.996567,71.902458]
# Russia, Koshurnikovo [54.307836,93.380709]
# Russia, Meleuz [52.959143,55.927672]
# Russia, Kondratovo [57.976023,56.108988]
# Russia, Khomutovka [51.922742,34.563238]
# Russia, Vershina Tei [53.246444,104.422037]
# Russia, Kayakent [42.386258,47.905456]
# Russia, Novokayakent [42.386098,47.989027]
# Russia, Ust-Kachka [58.003984,55.673701]
# Russia, Barguzin [53.616427,109.629858]
# Russia, Cherepanova [55.902227,64.391949]
# Russia, Kysyl-Syr [63.895474,122.758548]
# Russia, Kosh-Agach [49.996476,88.66167]
# Russia, Ishkin [51.566807,91.475149]
# Russia, Odintsovo (derevnya) [55.679138,37.263663]
# Russia, Akhtubinsk [48.284884,46.164422]
# Russia, Bogorodskoe (selo) [52.367493,140.436988]
# Russia, Naginskoe [61.698657,99.505405]
# Russia, Nogliki [51.812203,143.153062]
# Russia, Deputatsky [69.391802,139.903775]
# Russia, Promyshlennaya  [54.916517,85.637654]
# Russia, 10 Km Avtodorogi Irkutsk-Shelekhovo Territoria [59.851833,32.334122]
# Russia, Belovo [54.42212,86.303701]
# Russia, Filippovka [57.425219,57.032492]
# Russia, Zlynka [52.427389,31.737084]
# Russia, Liskinskoe [51.024614,39.547172]
# Russia, Vyazma [55.205944,34.298037]
# Russia, Malaya Minusa [53.730235,91.784044]
# Russia, Akyulovo [51.898502,57.500236]
# Russia, Staromaryevka [45.090883,42.221699]
# Russia, Vizma [59.897311,37.086003]
# Russia, Fruktovaya [54.91705,39.260834]
# Russia, Khmyzovka [50.339861,38.960087]
# Russia, Smolyanka [52.142799,113.513033]
# Russia, Kosterevo [57.246621,35.009053]
# Russia, Novy Chechen [44.25467,47.071002]
# Russia, Novye Burasy [52.12972,46.076468]
# Russia, Altay (poselok) [50.73624,87.015454]
# Russia, Podolsk (selo) [55.431136,37.544997]
# Russia, Khormaly [55.297256,47.259684]
# Russia, Baxan [61.698657,99.505405]
# Russia, Kirzhach [56.161945,38.871585]
# Russia, Zhovnets [52.873187,31.956228]
# Russia, Kuleshovka [47.077253,39.558661]
# Russia, Korsakov [46.63498,142.782579]
# Russia, Chaltyr [47.282673,39.499157]
# Russia, Khilok [51.363406,110.459021]
# Russia, Ermolino [55.535814,37.707224]
# Russia, Cheboxary (derevnya) [52.872508,40.965827]
# Russia, Plyos [57.460583,41.512263]
# Russia, Bazarny Karabulak [52.279892,46.408495]
# Russia, Kishleevo [56.241504,40.025677]
# Russia, Orenburgskoe [46.798035,134.239161]
# Russia, Peleduy [59.631696,112.751441]
# Russia, Kuzino [57.019168,59.439582]
# Russia, Plavitsa [52.243848,40.343986]
# Russia, Kukshumy [55.876874,46.335947]
# Russia, Shakhtersk [49.190343,142.076171]
# Russia, Samagaltay [50.600446,95.005079]
# Russia, Chekhov (selo) [55.14235,37.454357]
# Russia, Krasnovka [48.371762,40.257245]
# Russia, Gubkin [51.283644,37.534757]
# Russia, Staraya Vichuga [57.265628,41.876979]
# Russia, Kuragan [55.441004,65.341118]
# Russia, Kinel [53.22101,50.634394]
# Russia, Volovo (selo) [52.024265,37.890696]
# Russia, Tes [53.866662,92.183291]
# Russia, Kordon [57.411348,57.916686]
# Russia, Kardonixkaya [43.86272,41.716513]
# Russia, Mamontovo [52.70841,81.627529]
# Russia, Scherbinka [55.501315,37.564554]
# Russia, Tokarevo [60.525301,28.784806]
# Russia, Olymsky [61.698657,99.505405]
# Russia, Gribanovo [55.744855,37.122897]
# Russia, Ossora [59.25147,163.07456]
# Russia, Shkola [56.21723,88.124954]
# Russia, Vladimir (selo) [56.129057,40.406635]
# Russia, Novopavlovsky [45.247553,40.707777]
# Russia, Mochily [54.33236,38.669661]
# Russia, Atyashevo (rabochy Poselok) [54.587062,46.083808]
# Russia, Grekhnev Pal [61.207871,40.292387]
# Russia, Kholmogory [64.232002,41.64728]
# Russia, Kusak [53.222514,78.93562]
# Russia, Navlya [52.827016,34.499197]
# Russia, Olonets [60.979719,32.972043]
# Russia, Shpankovo [59.497089,29.843624]
# Russia, Novobalakovo [55.135068,54.26295]
# Russia, Podozersky [57.215964,40.338345]
# Russia, Mechetinskaya [47.026103,41.095957]
# Russia, Schelkovo (derevnya) [55.997749,42.899774]
# Russia, Ovsyannikovo [52.927756,86.083515]
# Russia, Bolgar [54.982239,49.022628]
# Russia, Kashkino [56.019792,56.994916]
# Russia, Deyskoe [61.698657,99.505405]
# Russia, Nikolo-Berezovka [61.698657,99.505405]
# Russia, Russkoe Dobrino [54.811788,20.875581]
# Russia, Podosinki (poselok) [56.20541,37.546785]
# Russia, Tobolsk [58.200891,68.253995]
# Russia, Mokhsogollokh [61.395259,128.936756]
# Russia, Kargopol [61.505339,38.948166]
# Russia, Novopavlovsk [43.957369,43.63191]
# Russia, Krasnoe Znamya [55.424776,37.295877]
# Russia, Axarka [61.698657,99.505405]
# Russia, Parfino [57.9703,31.648474]
# Russia, Sug-Axy [51.401187,91.276343]
# Russia, Anos [51.499828,85.945551]
# Russia, Mezhdurechensk (pgt) [53.685199,88.080398]
# Russia, Voloshovo [58.736669,29.301248]
# Russia, Checheninskaya [60.449337,41.218298]
# Russia, Atyuryevo [54.320567,43.34117]
# Russia, Zagaynovo [52.866588,84.532474]
# Russia, Shlisselburg [59.944959,31.034754]
# Russia, Saskal [51.645313,126.919607]
# Russia, Borisoglebsky [55.754411,37.590003]
# Russia, Shakhty (poselok) [47.709237,40.215401]
# Russia, Nizhny Odes [56.326797,44.006516]
# Russia, Ordynskoe [54.367147,81.899575]
# Russia, Partizanskoe [55.499846,94.394422]
# Russia, Chetvertoe Otdelenie Psikhonevrologicheskogo Dispansera [58.371086,49.553335]
# Russia, Khurba [50.404126,136.887277]
# Russia, Kurkachi [56.011042,49.564528]
# Russia, Progress [43.592407,39.832773]
# Russia, Pushkinskie Gory [54.894948,38.604048]
# Russia, Linda (lindovsky S/s) [56.61561,44.096752]
# Russia, Kudara [52.228234,106.656246]
# Russia, Kulotino [58.455781,33.367391]
# Russia, Karabulak [43.310593,44.900906]
# Russia, Kommunar [59.621609,30.393483]
# Russia, Ostashkov [57.15605,33.102873]
# Russia, Kirovskoe [46.062554,28.859501]
# Russia, Aniva [46.720816,142.521879]
# Russia, Malaya Inya [50.447826,86.682583]
# Russia, Alkino-2 [54.654511,55.592493]
# Russia, Zapolyarny [69.426135,30.820524]
# Russia, Igoshino [54.812738,41.940436]
# Russia, Yalta [44.497415,34.169506]
# Russia, Kulebaki [55.429716,42.512492]
# Russia, Gorodskoy Okrug Stavropol [45.041394,41.910513]
# Russia, Prokhorovka [51.034312,36.733271]
# Russia, Sibirtsevo [44.206156,132.445539]
# Russia, Zauralsky [54.791243,61.229134]
# Russia, Golyshmanovo (selo) [56.396005,68.375385]
# Russia, Zhilevo [54.984295,38.024455]
# Russia, Maryevka (otdelenie Sovkhoza Rossia) [52.556465,49.450936]
# Russia, Dzhangamakhi [42.444502,47.382224]
# Russia, Bykovo (poselok) [55.629135,38.070817]
# Russia, Znamenskoe [55.67761,37.588018]
# Russia, Ural [59.251903,59.455069]
# Russia, Onguday [50.749658,86.133784]
# Russia, Maslyansky [55.930115,70.13725]
# Russia, Yunost [55.920673,38.127187]

# %%
len(encoded_data)
# Out:
# 1000

# %%
import pandas as pd

# %%
ch_data2 = [w[8:] for w in ch_data]

# %%
df = pd.DataFrame(encoded_data, ch_data2[:1000])

# %%
df.to_csv("coord_city5.csv")
